# %%
import pandas as pd
import numpy as np

# %%
groceries = pd.Series(data=[30, 6, 'Yes', 'No'], index=['eggs', 'apples', 'milk', 'bread'])
print(groceries)
print()

print('Groceries has shape:', groceries.shape)
print('Groceries has dimension:', groceries.ndim)
print('Groceries has a total of', groceries.size, 'elements')
print()

print('The data in Groceries is:', groceries.values)
print('The index of Groceries is:', groceries.index)
print()

print('Is bananas an index label in Groceries:', 'bananas' in groceries)
print('Is bread an index label in Groceries:', 'bread' in groceries)
print()
# Out:
# eggs       30
# apples      6
# milk      Yes
# bread      No
# dtype: object
#
# Groceries has shape: (4,)
# Groceries has dimension: 1
# Groceries has a total of 4 elements
#
# The data in Groceries is: [30 6 'Yes' 'No']
# The index of Groceries is: Index(['eggs', 'apples', 'milk', 'bread'], dtype='object')
#
# Is bananas an index label in Groceries: False
# Is bread an index label in Groceries: True

# %%
groceries = pd.Series(data=[30, 6, 'Yes', 'No'], index=['eggs', 'apples', 'milk', 'bread'])

print('groceries[\'eggs\']:')
print(groceries['eggs'])
print()

print('groceries[[\'milk\', \'bread\']]:')
print(groceries[['milk', 'bread']])
print()

print('groceries[0]:')
print(groceries[0])
print()

print('groceries[[0, 1]]:')
print(groceries[[0, 1]])
print()

# Reduce ambiguity between index and label values (e.g. index 0 vs index value equal to 0)
print('groceries.loc[[\'eggs\', \'apples\']]:')
print(groceries.loc[['eggs', 'apples']])
print()

print('groceries.iloc[[2, 3]]:')
print(groceries.iloc[[2, 3]])
print()

print('Set groceries[\'eggs\'] = 2:')
groceries['eggs'] = 2
print(groceries)
print()

print('drop data with index \'apples\' out of place:')
print('groceries.drop(\'apples\')')
groceries.drop('apples')
print(groceries)
print()

print('drop data with index \'apples\' in place:')
print('groceries.drop(\'apples\', inplace=True)')
groceries.drop('apples', inplace=True)
print(groceries)
print()
# Out:
# groceries['eggs']:
# 30
#
# groceries[['milk', 'bread']]:
# milk     Yes
# bread     No
# dtype: object
#
# groceries[0]:
# 30
#
# groceries[[0, 1]]:
# eggs      30
# apples     6
# dtype: object
#
# groceries.loc[['eggs', 'apples']]:
# eggs      30
# apples     6
# dtype: object
#
# groceries.iloc[[2, 3]]:
# milk     Yes
# bread     No
# dtype: object
#
# Set groceries['eggs'] = 2:
# eggs        2
# apples      6
# milk      Yes
# bread      No
# dtype: object
#
# drop data with index 'apples' out of place:
# groceries.drop('apples')
# eggs        2
# apples      6
# milk      Yes
# bread      No
# dtype: object
#
# drop data with index 'apples' in place:
# groceries.drop('apples', inplace=True)
# eggs       2
# milk     Yes
# bread     No
# dtype: object

# %%
fruits = pd.Series([10, 6, 3], ['apples', 'oranges', 'bananas'])
print('fruits=')
print(fruits)
print()

print('fruits + 2:\n', fruits + 2) # We add 2 to each item in fruits
print()

print('fruits - 2:\n', fruits - 2) # We subtract 2 to each item in fruits
print()

print('fruits * 2:\n', fruits * 2) # We multiply each item in fruits by 2 
print()

print('fruits / 2:\n', fruits / 2) # We divide each item in fruits by 2
print()

print('EXP(X) = \n', np.exp(fruits))
print()

print('SQRT(X) =\n', np.sqrt(fruits))
print()

print('POW(X,2) =\n',np.power(fruits,2)) # We raise all elements of fruits to the power of 2
print()

print('Amount of bananas + 2 = ', fruits['bananas'] + 2)
print()

# We subtract 2 from apples
print('Amount of apples - 2 = ', fruits.iloc[0] - 2)
print()

# We multiply apples and oranges by 2
print('We double the amount of apples and oranges:\n', fruits[['apples', 'oranges']] * 2)
print()

# We divide apples and oranges by 2
print('We half the amount of apples and oranges:\n', fruits.loc[['apples', 'oranges']] / 2)
# Out:
# fruits=
# apples     10
# oranges     6
# bananas     3
# dtype: int64
#
# fruits + 2:
#  apples     12
# oranges     8
# bananas     5
# dtype: int64
#
# fruits - 2:
#  apples     8
# oranges    4
# bananas    1
# dtype: int64
#
# fruits * 2:
#  apples     20
# oranges    12
# bananas     6
# dtype: int64
#
# fruits / 2:
#  apples     5.0
# oranges    3.0
# bananas    1.5
# dtype: float64
#
# EXP(X) =
#  apples     22026.465795
# oranges      403.428793
# bananas       20.085537
# dtype: float64
#
# SQRT(X) =
#  apples     3.162278
# oranges    2.449490
# bananas    1.732051
# dtype: float64
#
# POW(X,2) =
#  apples     100
# oranges     36
# bananas      9
# dtype: int64
#
# Amount of bananas + 2 =  5
#
# Amount of apples - 2 =  8
#
# We double the amount of apples and oranges:
#  apples     20
# oranges    12
# dtype: int64
#
# We half the amount of apples and oranges:
#  apples     5.0
# oranges    3.0
# dtype: float64

# %%
########################################################
# Quiz 1: Manipulate a Series
########################################################

# Given a list representing a few planets
planets = ['Earth', 'Saturn', 'Venus', 'Mars', 'Jupiter']

# Given another list representing the distance of each of these planets from the Sun
# The distance from the Sun is in units of 10^6 km
distance_from_sun = [149.6, 1433.5, 108.2, 227.9, 778.6]

# TO DO: Create a Pandas Series "dist_planets" using the lists above, representing the distance of the planet from the Sun.
# Use the `distance_from_sun` as your data, and `planets` as your index.
dist_planets = pd.Series(distance_from_sun, planets)

# TO DO: Calculate the time (minutes) it takes light from the Sun to reach each planet. 
# You can do this by dividing each planet's distance from the Sun by the speed of light.
# Use the speed of light, c = 18, since light travels 18 x 10^6 km/minute.
c = 18
time_light = dist_planets / c

# TO DO: Use Boolean indexing to select only those planets for which sunlight takes less
# than 40 minutes to reach them.
# We'll check your work by printing out these close planets.
close_planets = time_light[time_light < 40]

# %%
items = {'Bob': pd.Series([245, 25, 55], index=['bike', 'pants', 'watch']),
         'Alice': pd.Series([40, 110, 500, 45], index=['book', 'glasses', 'bike', 'pants'])}
shopping_carts = pd.DataFrame(items)
shopping_carts
# Out:
#            Bob  Alice
# bike     245.0  500.0
# book       NaN   40.0
# glasses    NaN  110.0
# pants     25.0   45.0
# watch     55.0    NaN

# %%
data = {'Bob': pd.Series([245, 25, 55]),
        'Alice': pd.Series([40, 110, 500, 45])}
df = pd.DataFrame(data)
df
# Out:
#      Bob  Alice
# 0  245.0     40
# 1   25.0    110
# 2   55.0    500
# 3    NaN     45

# %%
print('shopping_carts has shape:', shopping_carts.shape)
print('shopping_carts has dimension:', shopping_carts.ndim)
print('shopping_carts has a total of:', shopping_carts.size, 'elements')
print()

print('The data in shopping_carts is:\n', shopping_carts.values)
print()

print('The row index in shopping_carts is:', shopping_carts.index)
print()

print('The column index in shopping_carts is:', shopping_carts.columns)
# Out:
# shopping_carts has shape: (5, 2)
# shopping_carts has dimension: 2
# shopping_carts has a total of: 10 elements
#
# The data in shopping_carts is:
#  [[245. 500.]
#  [ nan  40.]
#  [ nan 110.]
#  [ 25.  45.]
#  [ 55.  nan]]
#
# The row index in shopping_carts is: Index(['bike', 'book', 'glasses', 'pants', 'watch'], dtype='object')
#
# The column index in shopping_carts is: Index(['Bob', 'Alice'], dtype='object')

# %%
bob_shopping_cart = pd.DataFrame(items, columns=['Bob'])
bob_shopping_cart
# Out:
#        Bob
# bike   245
# pants   25
# watch   55

# %%
sel_shopping_cart = pd.DataFrame(items, index=['pants', 'book'])
sel_shopping_cart
# Out:
#         Bob  Alice
# pants  25.0     45
# book    NaN     40

# %%
alice_sel_shopping_cart = pd.DataFrame(items, index=['glasses', 'bike'], columns=['Alice'])
alice_sel_shopping_cart
# Out:
#          Alice
# glasses    110
# bike       500

# %%
data = {'Integers' : [1,2,3],
        'Floats' : [4.5, 8.2, 9.6]}

df = pd.DataFrame(data)
df
# Out:
#    Integers  Floats
# 0         1     4.5
# 1         2     8.2
# 2         3     9.6

# %%
data = {'Integers' : [1,2,3],
        'Floats' : [4.5, 8.2, 9.6]}

df = pd.DataFrame(data, index = ['label 1', 'label 2', 'label 3'])
df
# Out:
#          Integers  Floats
# label 1         1     4.5
# label 2         2     8.2
# label 3         3     9.6

# %%
items2 = [{'bikes': 20, 'pants': 30, 'watches': 35}, 
          {'watches': 10, 'glasses': 50, 'bikes': 15, 'pants':5}]

store_items = pd.DataFrame(items2)
store_items
# Out:
#    bikes  pants  watches  glasses
# 0     20     30       35      NaN
# 1     15      5       10     50.0

# %%
items2 = [{'bikes': 20, 'pants': 30, 'watches': 35}, 
          {'watches': 10, 'glasses': 50, 'bikes': 15, 'pants':5}]

store_items = pd.DataFrame(items2, index = ['store 1', 'store 2'])
store_items
# Out:
#          bikes  pants  watches  glasses
# store 1     20     30       35      NaN
# store 2     15      5       10     50.0

# %%
data = np.zeros((2,), dtype=[("A", "i4"), ("B", "f4"), ("C", "a10")])
data
# Out:
# array([(0, 0., b''), (0, 0., b'')],
#       dtype=[('A', '<i4'), ('B', '<f4'), ('C', 'S10')])

# %%
items = [{'bikes': 20, 'pants': 30, 'watches': 35}, 
          {'watches': 10, 'glasses': 50, 'bikes': 15, 'pants':5}]

store_items = pd.DataFrame(items, index = ['store 1', 'store 2'])
store_items
# Out:
#          bikes  pants  watches  glasses
# store 1     20     30       35      NaN
# store 2     15      5       10     50.0

# %%
print('How many bikes are in each store:\n', store_items[['bikes']])
print()

print('How many bikes and pants are in each store:\n', store_items[['bikes', 'pants']])
print()

print('What items are in Store 1:\n', store_items.loc[['store 1']])
print()

print('How many bikes are in Store 2:', store_items['bikes']['store 2'])
print()
# Out:
# How many bikes are in each store:
#           bikes
# store 1     20
# store 2     15
#
# How many bikes and pants are in each store:
#           bikes  pants
# store 1     20     30
# store 2     15      5
#
# What items are in Store 1:
#           bikes  pants  watches  glasses
# store 1     20     30       35      NaN
#
# How many bikes are in Store 2: 15

# %%
store_items[['bikes']]
# Out:
#          bikes
# store 1     20
# store 2     15

# %%
store_items[['bikes', 'pants']]
# Out:
#          bikes  pants
# store 1     20     30
# store 2     15      5

# %%
store_items.loc[['store 1']]
# Out:
#          bikes  pants  watches  glasses
# store 1     20     30       35      NaN

# %%
store_items['bikes']['store 2']
# Out:
# 15

# %%
store_items['shirts'] = [15, 2]
store_items
# Out:
#          bikes  pants  watches  glasses  shirts
# store 1     20     30       35      NaN      15
# store 2     15      5       10     50.0       2

# %%
store_items['suits'] = store_items['pants'] + store_items['shirts']
store_items
# Out:
#          bikes  pants  watches  glasses  shirts  suits
# store 1     20     30       35      NaN      15     45
# store 2     15      5       10     50.0       2      7

# %%
new_items = [{'bikes': 20, 'pants': 30, 'watches': 35, 'glasses': 4}]
new_store = pd.DataFrame(new_items, index=['store 3'])
new_store
# Out:
#          bikes  pants  watches  glasses
# store 3     20     30       35        4

# %%
store_items = pd.concat([store_items, new_store])
store_items
# Out:
#          bikes  pants  watches  glasses  shirts  suits
# store 1     20     30       35      NaN    15.0   45.0
# store 2     15      5       10     50.0     2.0    7.0
# store 3     20     30       35      4.0     NaN    NaN

# %%
store_items['new watches'] = store_items['watches'][1:]
store_items
# Out:
#          bikes  pants  watches  glasses  shirts  suits  new watches
# store 1     20     30       35      NaN    15.0   45.0          NaN
# store 2     15      5       10     50.0     2.0    7.0         10.0
# store 3     20     30       35      4.0     NaN    NaN         35.0

# %%
store_items.insert(5, 'shoes', [8, 5, 0])
store_items
# Out:
#          bikes  pants  watches  glasses  shirts  shoes  suits  new watches
# store 1     20     30       35      NaN    15.0      8   45.0          NaN
# store 2     15      5       10     50.0     2.0      5    7.0         10.0
# store 3     20     30       35      4.0     NaN      0    NaN         35.0

# %%
store_items.pop('new watches')
store_items
# Out:
#          bikes  pants  watches  glasses  shirts  shoes  suits
# store 1     20     30       35      NaN    15.0      8   45.0
# store 2     15      5       10     50.0     2.0      5    7.0
# store 3     20     30       35      4.0     NaN      0    NaN

# %%
store_items = store_items.drop(['watches', 'shoes'], axis=1)
store_items
# Out:
#          bikes  pants  glasses  shirts  suits
# store 1     20     30      NaN    15.0   45.0
# store 2     15      5     50.0     2.0    7.0
# store 3     20     30      4.0     NaN    NaN

# %%
store_items = store_items.drop(['store 1', 'store 2'], axis=0)
store_items
# Out:
#          bikes  pants  glasses  shirts  suits
# store 3     20     30      4.0     NaN    NaN

# %%
store_items = store_items.rename(columns={'bikes': 'hats'})
store_items
# Out:
#          hats  pants  glasses  shirts  suits
# store 3    20     30      4.0     NaN    NaN

# %%
store_items = store_items.rename(index={'store 3': 'last store'})
store_items
# Out:
#             hats  pants  glasses  shirts  suits
# last store    20     30      4.0     NaN    NaN

# %%
store_items = store_items.set_index('pants') # use column value as row index
store_items
# Out:
#        hats  glasses  shirts  suits
# pants
# 30       20      4.0     NaN    NaN

# %%
store_items.loc[[30]]
# Out:
#        hats  glasses  shirts  suits
# pants
# 30       20      4.0     NaN    NaN

# %%
items = [{'bikes': 20, 'pants': 30, 'watches': 35, 'shirts': 15, 'shoes': 8, 'suits': 45},
         {'watches': 10, 'glasses': 50, 'bikes': 15, 'pants': 5, 'shirts': 2, 'shoes': 5, 'suits': 7},
         {'bikes': 20, 'pants': 30, 'watches': 35, 'glasses': 4, 'shoes': 10}]

store_items = pd.DataFrame(items, index=['store 1', 'store 2', 'store 3'])
store_items
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0      NaN
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     NaN     10    NaN      4.0

# %%
print('NaN items in dataframe:')
print(store_items.isnull())
print()

print('Number of NaN values in each column:')
print(store_items.isnull().sum())
print()

print('Number of non-NaN values in each column:')
print(store_items.count())
print()

print('Total number of NaN values in dataframe:', store_items.isnull().sum().sum())
print()
# Out:
# NaN items in dataframe:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1  False  False    False   False  False  False     True
# store 2  False  False    False   False  False  False    False
# store 3  False  False    False    True  False   True    False
#
# Number of NaN values in each column:
# bikes      0
# pants      0
# watches    0
# shirts     1
# shoes      0
# suits      1
# glasses    1
# dtype: int64
#
# Number of non-NaN values in each column:
# bikes      3
# pants      3
# watches    3
# shirts     2
# shoes      3
# suits      2
# glasses    2
# dtype: int64
#
# Total number of NaN values in dataframe: 3

# %%
print('Drop rows with NaN values:')
store_items.dropna(axis=0)
# Out:
# Drop rows with NaN values:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 2     15      5       10     2.0      5    7.0     50.0

# %%
print('Drop columns with NaN values:')
store_items.dropna(axis=1) # can set inplace=True
# Out:
# Drop columns with NaN values:
#          bikes  pants  watches  shoes
# store 1     20     30       35      8
# store 2     15      5       10      5
# store 3     20     30       35     10

# %%
print('Fill NaN values with 0:')
store_items.fillna(0)
# Out:
# Fill NaN values with 0:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0      0.0
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     0.0     10    0.0      4.0

# %%
print('Fill NaN values with previous value in column:')
store_items.fillna(method='ffill', axis=0)
# Out:
# Fill NaN values with previous value in column:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0      NaN
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     2.0     10    7.0      4.0

# %%
print('Fill NaN values with previous value in row:')
store_items.fillna(method='ffill', axis=1)
# Out:
# Fill NaN values with previous value in row:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1   20.0   30.0     35.0    15.0    8.0   45.0     45.0
# store 2   15.0    5.0     10.0     2.0    5.0    7.0     50.0
# store 3   20.0   30.0     35.0    35.0   10.0   10.0      4.0

# %%
print('Fill NaN values with next value in column:')
store_items.fillna(method='backfill', axis=0)
# Out:
# Fill NaN values with next value in column:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0     50.0
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     NaN     10    NaN      4.0

# %%
print('Fill NaN values with next value in row:')
store_items.fillna(method='backfill', axis=1)
# Out:
# Fill NaN values with next value in row:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1   20.0   30.0     35.0    15.0    8.0   45.0      NaN
# store 2   15.0    5.0     10.0     2.0    5.0    7.0     50.0
# store 3   20.0   30.0     35.0    10.0   10.0    4.0      4.0

# %%
store_items
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0      NaN
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     NaN     10    NaN      4.0

# %%
print('Fill NaN values with linear interpolation by columns:')
store_items.interpolate(method='linear', axis=0)
# Out:
# Fill NaN values with linear interpolation by columns:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0      NaN
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     2.0     10    7.0      4.0

# %%
print('Fill NaN values with linear interpolation by rows:')
store_items.interpolate(method='linear', axis=1)
# Out:
# Fill NaN values with linear interpolation by rows:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1   20.0   30.0     35.0    15.0    8.0   45.0     45.0
# store 2   15.0    5.0     10.0     2.0    5.0    7.0     50.0
# store 3   20.0   30.0     35.0    22.5   10.0    7.0      4.0

# %%
########################################################
# Quiz 1: Manipulate a DataFrame
########################################################

# Set the precision of our dataframes to one decimal place.
pd.set_option('display.precision', 1)

# Create a Pandas DataFrame that contains the ratings some users have given to a series of books. 
# The ratings given are in the range from 1 to 5, with 5 being the best score. 
# The names of the books, the corresponding authors, and the ratings of each user are given below:

books = pd.Series(data = ['Great Expectations', 'Of Mice and Men', 'Romeo and Juliet', 'The Time Machine', 'Alice in Wonderland' ])
authors = pd.Series(data = ['Charles Dickens', 'John Steinbeck', 'William Shakespeare', ' H. G. Wells', 'Lewis Carroll' ])

# User ratings are in the order of the book titles mentioned above
# If a user has not rated all books, Pandas will automatically consider the missing values as NaN.
# If a user has mentioned `np.nan` value, then also it means that the user has not yet rated that book.
user_1 = pd.Series(data = [3.2, np.nan ,2.5])
user_2 = pd.Series(data = [5., 1.3, 4.0, 3.8])
user_3 = pd.Series(data = [2.0, 2.3, np.nan, 4])
user_4 = pd.Series(data = [4, 3.5, 4, 5, 4.2])


# Use the data above to create a Pandas DataFrame that has the following column
# labels: 'Author', 'Book Title', 'User 1', 'User 2', 'User 3', 'User 4'. 
# Let Pandas automatically assign numerical row indices to the DataFrame. 

# TO DO: Create a dictionary with the data given above
dat = {'Author': authors, 'Book Title': books, 'User 1': user_1, 'User 2': user_2, 'User 3': user_3, 'User 4': user_4}

# TO DO: Create a Pandas DataFrame using the dictionary created above
book_ratings = pd.DataFrame(dat)
#dat = pd.DataFrame([authors, books, user_1, user_2, user_3, user_4], 
#                   columns=['Authors', 'Book Title', 'User 1', 'User 2', 'User 3', 'User 4'])

# TO DO:
# If you created the dictionary correctly you should have a Pandas DataFrame
# that has column labels: 
# 'Author', 'Book Title', 'User 1', 'User 2', 'User 3', 'User 4' 
# and row indices 0 through 4.

# Now replace all the NaN values in your DataFrame with the average rating in
# each column. Replace the NaN values in place. 
# HINT: Use the `pandas.DataFrame.fillna(value, inplace = True)` function for substituting the NaN values. 
# Write your code below:
book_ratings.fillna(book_ratings[['User 1', 'User 2', 'User 3', 'User 4']].mean(), inplace=True)
book_ratings
# Out:
#                Authors           Book Title  User 1  User 2  User 3  User 4
# 0      Charles Dickens   Great Expectations     3.2     5.0     2.0     4.0
# 1       John Steinbeck      Of Mice and Men     2.9     1.3     2.3     3.5
# 2  William Shakespeare     Romeo and Juliet     2.5     4.0     2.8     4.0
# 3          H. G. Wells     The Time Machine     2.9     3.8     4.0     5.0
# 4        Lewis Carroll  Alice in Wonderland     2.9     3.5     2.8     4.2

# %%
#From the DataFrame above can you now pick all the books that had a rating of 5?
#Hint - You can do this in just one line of code, by using pandas.DataFrame.any. Try to do it yourself first, you'll find the answer below:
#book_ratings[book_ratings.isin([5]).any(axis=1)]['Book Title'].values
book_ratings[(book_ratings == 5).any(axis=1)]['Book Title'].values
# Out:
# array(['Great Expectations', 'The Time Machine'], dtype=object)

# %%
google_stock = pd.read_csv('./GOOG.csv')

print(type(google_stock))
print(google_stock.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (3313, 7)

# %%
google_stock
# Out:
#             Date   Open   High    Low  Close  Adj Close    Volume
# 0     2004-08-19   49.7   51.7   47.7   49.8       49.8  44994500
# 1     2004-08-20   50.2   54.2   49.9   53.8       53.8  23005800
# 2     2004-08-23   55.0   56.4   54.2   54.3       54.3  18393200
# 3     2004-08-24   55.3   55.4   51.5   52.1       52.1  15361800
# 4     2004-08-25   52.1   53.7   51.6   52.7       52.7   9257400
# ...          ...    ...    ...    ...    ...        ...       ...
# 3308  2017-10-09  980.0  985.4  976.1  977.0      977.0    891400
# 3309  2017-10-10  980.0  981.6  966.1  972.6      972.6    968400
# 3310  2017-10-11  973.7  990.7  972.2  989.2      989.2   1693300
# 3311  2017-10-12  987.5  994.1  985.0  987.8      987.8   1262400
# 3312  2017-10-13  992.0  997.2  989.0  989.7      989.7   1157700
#
# [3313 rows x 7 columns]

# %%
google_stock.head()
# google_stock.head(2) - returns first 2 rows
# Out:
#          Date  Open  High   Low  Close  Adj Close    Volume
# 0  2004-08-19  49.7  51.7  47.7   49.8       49.8  44994500
# 1  2004-08-20  50.2  54.2  49.9   53.8       53.8  23005800
# 2  2004-08-23  55.0  56.4  54.2   54.3       54.3  18393200
# 3  2004-08-24  55.3  55.4  51.5   52.1       52.1  15361800
# 4  2004-08-25  52.1  53.7  51.6   52.7       52.7   9257400

# %%
google_stock.tail()
# google_stock.tail(8) - returns last 8 rows
# Out:
#             Date   Open   High    Low  Close  Adj Close   Volume
# 3308  2017-10-09  980.0  985.4  976.1  977.0      977.0   891400
# 3309  2017-10-10  980.0  981.6  966.1  972.6      972.6   968400
# 3310  2017-10-11  973.7  990.7  972.2  989.2      989.2  1693300
# 3311  2017-10-12  987.5  994.1  985.0  987.8      987.8  1262400
# 3312  2017-10-13  992.0  997.2  989.0  989.7      989.7  1157700

# %%
google_stock.isnull().any(axis=0)
# Out:
# Date         False
# Open         False
# High         False
# Low          False
# Close        False
# Adj Close    False
# Volume       False
# dtype: bool

# %%
google_stock.describe()
# Out:
#          Open    High     Low   Close  Adj Close   Volume
# count  3313.0  3313.0  3313.0  3313.0     3313.0  3.3e+03
# mean    380.2   383.5   376.5   380.1      380.1  8.0e+06
# std     223.8   225.0   222.5   223.9      223.9  8.4e+06
# min      49.3    50.5    47.7    49.7       49.7  7.9e+03
# 25%     226.6   228.4   224.0   226.4      226.4  2.6e+06
# 50%     293.3   295.4   289.9   293.0      293.0  5.3e+06
# 75%     536.7   540.0   532.4   536.7      536.7  1.1e+07
# max     992.0   997.2   989.0   989.7      989.7  8.3e+07

# %%
google_stock['Adj Close'].describe()
# Out:
# count    3313.0
# mean      380.1
# std       223.9
# min        49.7
# 25%       226.4
# 50%       293.0
# 75%       536.7
# max       989.7
# Name: Adj Close, dtype: float64

# %%
google_stock.max()
# Out:
# Date         2017-10-13
# Open              992.0
# High              997.2
# Low               989.0
# Close             989.7
# Adj Close         989.7
# Volume         82768100
# dtype: object

# %%
pd.set_option('display.precision', 3)
google_stock[google_stock.columns[1:]].mean(axis=0)
# Out:
# Open         3.802e+02
# High         3.835e+02
# Low          3.765e+02
# Close        3.801e+02
# Adj Close    3.801e+02
# Volume       8.038e+06
# dtype: float64

# %%
google_stock['Close'].min()
# Out:
# 49.681866

# %%
google_stock.corr()
# Out:
#             Open   High    Low  Close  Adj Close  Volume
# Open       1.000  1.000  1.000  1.000      1.000  -0.564
# High       1.000  1.000  1.000  1.000      1.000  -0.563
# Low        1.000  1.000  1.000  1.000      1.000  -0.567
# Close      1.000  1.000  1.000  1.000      1.000  -0.565
# Adj Close  1.000  1.000  1.000  1.000      1.000  -0.565
# Volume    -0.564 -0.563 -0.567 -0.565     -0.565   1.000

# %%
data = pd.read_csv('./fake_company.csv')
data
# Out:
#    Year     Name Department  Age  Salary
# 0  1990    Alice         HR   25   50000
# 1  1990      Bob         RD   30   48000
# 2  1990  Charlie      Admin   45   55000
# 3  1991   Dakota         HR   26   52000
# 4  1991     Elsa         RD   31   50000
# 5  1991    Frank      Admin   46   60000
# 6  1992    Grace      Admin   27   60000
# 7  1992  Hoffman         RD   32   52000
# 8  1992    Inaar      Admin   28   62000

# %%
data.groupby(['Year'])['Salary'].sum()
# Out:
# Year
# 1990    153000
# 1991    162000
# 1992    174000
# Name: Salary, dtype: int64

# %%
data.groupby(['Year'])['Salary'].mean()
# Out:
# Year
# 1990    51000.0
# 1991    54000.0
# 1992    58000.0
# Name: Salary, dtype: float64

# %%
data.groupby(['Name'])['Salary'].sum()
# Out:
# Name
# Alice      50000
# Bob        48000
# Charlie    55000
# Dakota     52000
# Elsa       50000
# Frank      60000
# Grace      60000
# Hoffman    52000
# Inaar      62000
# Name: Salary, dtype: int64

# %%
data.groupby(['Year', 'Department'])['Salary'].sum()
# Out:
# Year  Department
# 1990  Admin          55000
#       HR             50000
#       RD             48000
# 1991  Admin          60000
#       HR             52000
#       RD             50000
# 1992  Admin         122000
#       RD             52000
# Name: Salary, dtype: int64

# %%
###############################################################################
#                         10 minutes to pandas                                #
###############################################################################

# %%
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))
df
# Out:
#                 A      B      C      D
# 2013-01-01 -0.399  3.121  0.104  2.234
# 2013-01-02 -1.766  0.052  0.818  1.827
# 2013-01-03  1.756  0.153  0.537 -0.931
# 2013-01-04 -0.177  2.245  1.411 -0.928
# 2013-01-05 -0.456  1.222 -0.336  1.587
# 2013-01-06  0.326  1.249  0.325  0.203

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp('20130102'),
        "C": pd.Series(1, index=list(range(4)), dtype='float32'),
        "D": np.array([3] * 4, dtype='int32'),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo"
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
print(df2.head())
print()
print(df2.tail(3))
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo
#
#      A          B    C  D      E    F
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
print(df.index)
print()
print(df.columns)
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')
#
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[-0.39904346,  3.1207567 ,  0.10438506,  2.23420486],
#        [-1.7661031 ,  0.05178777,  0.81812343,  1.82706384],
#        [ 1.75638462,  0.15331799,  0.53741325, -0.93109836],
#        [-0.17696938,  2.2449427 ,  1.41077161, -0.92807317],
#        [-0.45598103,  1.22159077, -0.33592847,  1.58707026],
#        [ 0.32610441,  1.24908831,  0.32504147,  0.20330067]])

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A      -0.399      -1.766       1.756      -0.177      -0.456       0.326
# B       3.121       0.052       0.153       2.245       1.222       1.249
# C       0.104       0.818       0.537       1.411      -0.336       0.325
# D       2.234       1.827      -0.931      -0.928       1.587       0.203

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                 D      C      B      A
# 2013-01-01  2.234  0.104  3.121 -0.399
# 2013-01-02  1.827  0.818  0.052 -1.766
# 2013-01-03 -0.931  0.537  0.153  1.756
# 2013-01-04 -0.928  1.411  2.245 -0.177
# 2013-01-05  1.587 -0.336  1.222 -0.456
# 2013-01-06  0.203  0.325  1.249  0.326

# %%
df.sort_values(by='B')
# Out:
#                 A      B      C      D
# 2013-01-02 -1.766  0.052  0.818  1.827
# 2013-01-03  1.756  0.153  0.537 -0.931
# 2013-01-05 -0.456  1.222 -0.336  1.587
# 2013-01-06  0.326  1.249  0.325  0.203
# 2013-01-04 -0.177  2.245  1.411 -0.928
# 2013-01-01 -0.399  3.121  0.104  2.234

# %%
df["20130102":"20130104"]
# Out:
#                 A      B      C      D
# 2013-01-02 -1.766  0.052  0.818  1.827
# 2013-01-03  1.756  0.153  0.537 -0.931
# 2013-01-04 -0.177  2.245  1.411 -0.928

# %%
df[0:3]
# Out:
#                 A      B      C      D
# 2013-01-01 -0.399  3.121  0.104  2.234
# 2013-01-02 -1.766  0.052  0.818  1.827
# 2013-01-03  1.756  0.153  0.537 -0.931

# %%
df["A"]
# Out:
# 2013-01-01   -0.399
# 2013-01-02   -1.766
# 2013-01-03    1.756
# 2013-01-04   -0.177
# 2013-01-05   -0.456
# 2013-01-06    0.326
# Freq: D, Name: A, dtype: float64

# %%
# from above:  dates = pd.date_range('20130101', periods=6)
df.loc[dates[0]]
# Out:
# A   -0.399
# B    3.121
# C    0.104
# D    2.234
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                 A      B
# 2013-01-01 -0.399  3.121
# 2013-01-02 -1.766  0.052
# 2013-01-03  1.756  0.153
# 2013-01-04 -0.177  2.245
# 2013-01-05 -0.456  1.222
# 2013-01-06  0.326  1.249

# %%
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                 A      B
# 2013-01-02 -1.766  0.052
# 2013-01-03  1.756  0.153
# 2013-01-04 -0.177  2.245

# %%
df.loc["20130102", ["A", "B"]]
# Out:
# A   -1.766
# B    0.052
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.loc[dates[0], "A"]
# Out:
# -0.39904345880223285

# %%
df.at[dates[0], "A"]
# Out:
# -0.39904345880223285

# %%
df.iloc[3]
# Out:
# A   -0.177
# B    2.245
# C    1.411
# D   -0.928
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                 A      B
# 2013-01-04 -0.177  2.245
# 2013-01-05 -0.456  1.222

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                 A      C
# 2013-01-02 -1.766  0.818
# 2013-01-03  1.756  0.537
# 2013-01-05 -0.456 -0.336

# %%
df.iloc[1:3, :]
# Out:
#                 A      B      C      D
# 2013-01-02 -1.766  0.052  0.818  1.827
# 2013-01-03  1.756  0.153  0.537 -0.931

# %%
df.iloc[:, 1:3]
# Out:
#                 B      C
# 2013-01-01  3.121  0.104
# 2013-01-02  0.052  0.818
# 2013-01-03  0.153  0.537
# 2013-01-04  2.245  1.411
# 2013-01-05  1.222 -0.336
# 2013-01-06  1.249  0.325

# %%
df.iloc[1, 1]
# Out:
# 0.051787765710002695

# %%
df.iat[1, 1]
# Out:
# 0.051787765710002695

# %%
df[df["A"] > 0]
# Out:
#                 A      B      C      D
# 2013-01-03  1.756  0.153  0.537 -0.931
# 2013-01-06  0.326  1.249  0.325  0.203

# %%
df[df > 0]
# Out:
#                 A      B      C      D
# 2013-01-01    NaN  3.121  0.104  2.234
# 2013-01-02    NaN  0.052  0.818  1.827
# 2013-01-03  1.756  0.153  0.537    NaN
# 2013-01-04    NaN  2.245  1.411    NaN
# 2013-01-05    NaN  1.222    NaN  1.587
# 2013-01-06  0.326  1.249  0.325  0.203

# %%
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three"]
df2
# Out:
#                 A      B      C      D      E
# 2013-01-01 -0.399  3.121  0.104  2.234    one
# 2013-01-02 -1.766  0.052  0.818  1.827    one
# 2013-01-03  1.756  0.153  0.537 -0.931    two
# 2013-01-04 -0.177  2.245  1.411 -0.928  three
# 2013-01-05 -0.456  1.222 -0.336  1.587   four
# 2013-01-06  0.326  1.249  0.325  0.203  three

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                 A      B      C      D     E
# 2013-01-03  1.756  0.153  0.537 -0.931   two
# 2013-01-05 -0.456  1.222 -0.336  1.587  four

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))
df["F"] = s1

# %%
df.at[dates[0], "A"] = 0
# df.iloc[0, 1] = 0
df
# Out:
#                 A      B      C  D    F
# 2013-01-01  0.000  0.000  0.104  5  NaN
# 2013-01-02 -1.766  0.052  0.818  5  1.0
# 2013-01-03  1.756  0.153  0.537  5  2.0
# 2013-01-04 -0.177  2.245  1.411  5  3.0
# 2013-01-05 -0.456  1.222 -0.336  5  4.0
# 2013-01-06  0.326  1.249  0.325  5  5.0

# %%
df.loc[:, "D"] = np.array([5] * len(df))
# df.loc[:, "D"] = np.array([5] * df.shape[0])
df
# Out:
#                 A      B      C  D    F
# 2013-01-01  0.000  0.000  0.104  5  NaN
# 2013-01-02 -1.766  0.052  0.818  5  1.0
# 2013-01-03  1.756  0.153  0.537  5  2.0
# 2013-01-04 -0.177  2.245  1.411  5  3.0
# 2013-01-05 -0.456  1.222 -0.336  5  4.0
# 2013-01-06  0.326  1.249  0.325  5  5.0

# %%
df1 = df.reindex(index=dates[:4], columns=list(df.columns) + ["E"])
df1.loc[dates[0:2], "E"] = 1
df1
# Out:
#                 A      B      C  D    F    E
# 2013-01-01  0.000  0.000  0.104  5  NaN  1.0
# 2013-01-02 -1.766  0.052  0.818  5  1.0  1.0
# 2013-01-03  1.756  0.153  0.537  5  2.0  NaN
# 2013-01-04 -0.177  2.245  1.411  5  3.0  NaN

# %%
df1.dropna(how='any')
# Out:
#                 A      B      C  D    F    E
# 2013-01-02 -1.766  0.052  0.818  5  1.0  1.0

# %%
df1.fillna(value=df1.mean())
# df1.fillna(value=5)
# Out:
#                 A      B      C  D    F    E
# 2013-01-01  0.000  0.000  0.104  5  2.0  1.0
# 2013-01-02 -1.766  0.052  0.818  5  1.0  1.0
# 2013-01-03  1.756  0.153  0.537  5  2.0  1.0
# 2013-01-04 -0.177  2.245  1.411  5  3.0  1.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis="index")
# Out:
#                 A      B      C    D    F
# 2013-01-01    NaN    NaN    NaN  NaN  NaN
# 2013-01-02    NaN    NaN    NaN  NaN  NaN
# 2013-01-03  0.756 -0.847 -0.463  4.0  1.0
# 2013-01-04 -3.177 -0.755 -1.589  2.0  0.0
# 2013-01-05 -5.456 -3.778 -5.336  0.0 -1.0
# 2013-01-06    NaN    NaN    NaN  NaN  NaN

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    3.522
# B    2.245
# C    1.747
# D    0.000
# F    4.000
# dtype: float64

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    1
# 1    5
# 2    0
# 3    2
# 4    1
# 5    5
# 6    3
# 7    2
# 8    2
# 9    3
# dtype: int32

# %%
s.value_counts()
# Out:
# 2    3
# 1    2
# 5    2
# 3    2
# 0    1
# dtype: int64

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#        0      1      2      3
# 0  1.304  0.550  0.018  0.649
# 1 -0.253  0.292 -0.310 -0.802
# 2 -0.270  0.874  0.989 -0.369
# 3 -1.163  1.779  1.006  0.019
# 4 -0.223  0.156  1.887  0.061
# 5 -1.714  0.741 -1.944  1.030
# 6 -0.977  2.523  1.112 -0.043
# 7 -1.904  0.383  1.710  1.388
# 8  0.025 -0.590 -2.287 -1.052
# 9  0.163 -0.434 -0.436 -0.503

# %%
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#        0      1      2      3
# 0  1.304  0.550  0.018  0.649
# 1 -0.253  0.292 -0.310 -0.802
# 2 -0.270  0.874  0.989 -0.369
# 3 -1.163  1.779  1.006  0.019
# 4 -0.223  0.156  1.887  0.061
# 5 -1.714  0.741 -1.944  1.030
# 6 -0.977  2.523  1.112 -0.043
# 7 -1.904  0.383  1.710  1.388
# 8  0.025 -0.590 -2.287 -1.052
# 9  0.163 -0.434 -0.436 -0.503

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)
df
# Out:
#      A      B      C      D
# 0  foo    one -0.049  0.840
# 1  bar    one -0.009 -0.071
# 2  foo    two -0.243  1.115
# 3  bar  three  0.065 -1.720
# 4  foo    two  0.867 -0.749
# 5  bar    two -0.022  1.292
# 6  foo    one  1.237  1.734
# 7  foo  three  0.740  0.143

# %%
df.groupby("A")[["C", "D"]].sum()
# Out:
#          C      D
# A
# bar  0.034 -0.499
# foo  2.551  3.083

# %%
df.groupby(["A", "B"]).sum()
# Out:
#                C      D
# A   B
# bar one   -0.009 -0.071
#     three  0.065 -1.720
#     two   -0.022  1.292
# foo one    1.188  2.574
#     three  0.740  0.143
#     two    0.623  0.366

# %%
tuples = list(
    zip(
        ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
        ["one", "two", "one", "two", "one", "two", "one", "two"],
    )
)

index = pd.MultiIndex.from_tuples(tuples, names=["first", "second"])

df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])

df2 = df[:4]

df2
# Out:
#                   A      B
# first second
# bar   one    -1.363 -0.549
#       two    -0.406  0.307
# baz   one    -2.528  0.217
#       two     0.196  1.085

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A   -1.363
#                B   -0.549
#        two     A   -0.406
#                B    0.307
# baz    one     A   -2.528
#                B    0.217
#        two     A    0.196
#                B    1.085
# dtype: float64

# %%
stacked.unstack()
# Out:
#                   A      B
# first second
# bar   one    -1.363 -0.549
#       two    -0.406  0.307
# baz   one    -2.528  0.217
#       two     0.196  1.085

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)
df
# Out:
#         A  B    C      D      E
# 0     one  A  foo -0.249 -0.864
# 1     one  B  foo -0.514 -0.380
# 2     two  C  foo  0.868 -1.264
# 3   three  A  bar -0.370 -0.295
# 4     one  B  bar  2.500  1.738
# 5     one  C  bar -0.766  1.317
# 6     two  A  foo -1.286 -0.546
# 7   three  B  foo  0.156 -0.403
# 8     one  C  foo  2.266 -0.691
# 9     one  A  bar  0.588 -0.332
# 10    two  B  bar  1.065  1.985
# 11  three  C  bar  0.177  0.062

# %%
test = pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
test
# Out:
# C          bar    foo
# A     B
# one   A  0.588 -0.249
#       B  2.500 -0.514
#       C -0.766  2.266
# three A -0.370    NaN
#       B    NaN  0.156
#       C  0.177    NaN
# two   A    NaN -1.286
#       B  1.065    NaN
#       C    NaN  0.868

# %%
test.iloc[3, 1]
# Out:
# nan

# %%
import matplotlib.pyplot as plt
plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
                  index=pd.date_range("1/1/2000", periods=1000),
                  columns=["A", "B", "C", "D"])

df = df.cumsum()
plt.figure();
df.plot();
plt.legend(loc='best')
